# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Precision5540\anaconda3\envs\First_Environment\python.exe

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
y = -115
type(y)
# Out:
# int

# %%
x = 4.5
x = int(x)
print(x)
type(x)
# Out:
# 4
# int

# %%
x = 55.5
type (x)
# Out:
# float

# %%
A = "Welcome to the class."
type(A)
# Out:
# str

# %%
x = 4
isinstance(x, int)
# Out:
# True
