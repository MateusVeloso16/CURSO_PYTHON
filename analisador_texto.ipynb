# %%
import string

print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
from collections import Counter

print(Counter(['a', 'b', 'a', 'c', 'b', 'a']))
print(Counter('abacba'))
# Out:
# Counter({'a': 3, 'b': 2, 'c': 1})
# Counter({'a': 3, 'b': 2, 'c': 1})

# %%
 print(string.ascii_letters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
print(string.ascii_lowercase)
# Out:
# abcdefghijklmnopqrstuvwxyz

# %%
print(string.digits)
# Out:
# 0123456789

# %%
from collections import Counter

print(Counter(['a', 'b', 'a', 'c', 'b', 'a']))
print(Counter('abacba'))
# Out:
# Counter({'a': 3, 'b': 2, 'c': 1})
# Counter({'a': 3, 'b': 2, 'c': 1})

# %%
def analisar_texto(texto):
    palavras = texto.split()
    contagem_palavras = len(palavras)
    frequencia_palavras = Counter(palavras)
    frequencia_letras = Counter(texto)

    return contagem_palavras, frequencia_palavras, frequencia_letras

texto = "Ola mundo! Este e um teste. Ola novamente."

contagem_palavras, frequencia_palavras, frequencia_letras = analisar_texto(texto)

print (f'Contagem de palavras: {contagem_palavras}\n',
       f'Frequencia de palavras: {frequencia_palavras}\n',
       f'Frequencia de letras: {frequencia_letras}')
# Out:
# Contagem de palavras: 8
#  Frequencia de palavras: Counter({'Ola': 2, 'mundo!': 1, 'Este': 1, 'e': 1, 'um': 1, 'teste.': 1, 'novamente.': 1})
#  Frequencia de letras: Counter({' ': 7, 'e': 6, 't': 4, 'a': 3, 'm': 3, 'n': 3, 'O': 2, 'l': 2, 'u': 2, 'o': 2, 's': 2, '.': 2, 'd': 1, '!': 1, 'E': 1, 'v': 1})

# %%
vogais = 'aeiou'
numeros = '12345'
remover = 'a'

guia_troca = str.maketrans(vogais, numeros, remover)
print(guia_troca)
# Out:
# {97: None, 101: 50, 105: 51, 111: 52, 117: 53}

# %%
letras_minusculas = string.ascii_lowercase

print(letras_minusculas.translate(guia_troca))
# Out:
# bcd2fgh3jklmn4pqrst5vwxyz

# %%
def analisar_texto(texto):

    '''
    Analisa o texto fornecido e calcula a contagem de palavras, a frequencia de palavras e a frequencia de letras.

    Parameters
    --------
    texto : str
        texto a ser analisado

    Returns
    --------
    Tuple
        Contagem de palavras, frequencia de palavras, frequencia de letras
    '''


    tratamento = str.maketrans('', '', string.punctuation)
    texto_tratado = texto.translate(tratamento)
    palavras = texto_tratado.split()
    contagem_palavras = len(palavras)
    frequencia_palavras = Counter(palavras)
    frequencia_letras = Counter(texto_tratado.lower())

    return contagem_palavras, frequencia_palavras, frequencia_letras

texto = "Ola mundo! Este e um teste. Ola novamente."

contagem_palavras, frequencia_palavras, frequencia_letras = analisar_texto(texto)

print (f'Contagem de palavras: {contagem_palavras}\n',
       f'Frequencia de palavras: {frequencia_palavras}\n',
       f'Frequencia de letras: {frequencia_letras}')
# Out:
# Contagem de palavras: 8
#  Frequencia de palavras: Counter({'Ola': 2, 'mundo': 1, 'Este': 1, 'e': 1, 'um': 1, 'teste': 1, 'novamente': 1})
#  Frequencia de letras: Counter({' ': 7, 'e': 7, 'o': 4, 't': 4, 'a': 3, 'm': 3, 'n': 3, 'l': 2, 'u': 2, 's': 2, 'd': 1, 'v': 1})
