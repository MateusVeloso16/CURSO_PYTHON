# %%
import pandas as pd

df = pd.read_csv('orders_raw_messy.csv')

df.head(), df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order id           26 non-null     int64
#  1   customer_name      25 non-null     object
#  2   email              26 non-null     object
#  3   signup_date        25 non-null     object
#  4   order_date         26 non-null     object
#  5   product            26 non-null     object
#  6   quantity           26 non-null     object
#  7   price_eur          26 non-null     object
#  8   total              10 non-null     object
#  9   country            25 non-null     object
#  10  city               25 non-null     object
#  11  status             26 non-null     object
#  12  phone              8 non-null      object
#  13  postal_code        23 non-null     object
#  14  newsletter_opt_in  22 non-null     object
#  15  notes              11 non-null     object
# ...

# %%
df.columns = (df.columns.str.strip())
df.columns = (df.columns.str.lower())
df.columns = (df.columns.str.replace(r"\s+", "_", regex=True))

df.columns
# Out:
# Index(['order_id', 'customer_name', 'email', 'signup_date', 'order_date',
#        'product', 'quantity', 'price_eur', 'total', 'country', 'city',
#        'status', 'phone', 'postal_code', 'newsletter_opt_in', 'notes'],
#       dtype='object')
